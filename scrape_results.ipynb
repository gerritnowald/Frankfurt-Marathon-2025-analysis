# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
url = "https://live.frankfurt-marathon.com/2023/?page=1&event=L_HCH3BKLB3B8&num_results=1000&pid=list&search%5Bsex%5D=M&search%5Bage_class%5D=%25"

# Send request with headers to mimic browser
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36'
}

response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.content, 'html.parser')

# Find all list items that contain runner information
runners = soup.find_all('li', class_='list-active list-group-item row')

# results = []
# for runner in runners:
#     # Extract runner data
#     place = runner.find('div', class_='type-place place-primary numeric').text.strip()
#     name = runner.find('h4', class_='list-field type-fullname').text.strip()
    
#     # Find all list-field divs
#     fields = runner.find_all('div', class_='list-field')
    
#     # Extract specific fields
#     bib_number = None
#     club_city = None
#     age_group = None
#     net_time = None
#     gun_time = None
    
#     for field in fields:
#         label = field.find('div', class_='list-label')
#         if label:
#             if 'Bib Number' in label.text:
#                 bib_number = field.text.replace('Bib Number', '').strip()
#             elif 'Club / City' in label.text:
#                 club_city = field.text.replace('Club / City', '').strip()
#             elif 'Age Group' in label.text:
#                 age_group = field.text.replace('Age Group', '').strip()
#             elif 'Net time' in label.text:
#                 net_time = field.text.replace('Net time', '').strip()
#             elif 'Gun time' in label.text:
#                 gun_time = field.text.replace('Gun time', '').strip()
    
#     runner_data = {
#         'Place': place,
#         'Name': name,
#         'Bib Number': bib_number,
#         'Club/City': club_city,
#         'Age Group': age_group,
#         'Net Time': net_time,
#         'Gun Time': gun_time
#     }
#     results.append(runner_data)

# # Create DataFrame
# df = pd.DataFrame(results)

# Save to CSV
# df.to_csv('marathon_results.csv', index=False)
# print(f"Scraped {len(results)} results to marathon_results.csv")

runners
# Out:
# [<li class="list-active list-group-item row">
#  <div class="col-xs-12 col-sm-12 col-md-5 list-field-wrap">
#  <div class="row">
#  <div class="list-field type-place place-primary numeric" style="width: 40px">1</div>
#  <div class="list-field type-place place-secondary hidden-xs numeric" style="width: 40px">1</div>
#  <h4 class="list-field type-fullname"><a href="?content=detail&amp;fpid=list&amp;pid=list&amp;idp=HCH3BKLB6675C2&amp;lang=EN_CAP&amp;event=L_HCH3BKLB3B8&amp;num_results=1000&amp;search%5Bsex%5D=M&amp;search%5Bage_class%5D=%25&amp;search_event=L_HCH3BKLB3B8">Asfaw, Belay (ETH)</a></h4>
#  </div>
#  </div>
#  <div class="col-xs-12 col-sm-12 col-md-7 list-field-wrap">
#  <div class="pull-left">
#  <div class="row">
#  <div class="list-field type-field" style="width: 50px"><div class="visible-xs-block visible-sm-block list-label">Bib Number</div>5</div>
# ...
